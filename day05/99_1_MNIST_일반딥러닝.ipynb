# %% [markdown]
# ### 사전준비

# %%
# 기본 패키지 import
import numpy as np
import pandas as pd
import scipy as sp

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 설정/차트 마이너스 깨짐현상 해결 / seaborn으로 화면설정
from matplotlib import rc
import matplotlib.font_manager as fm

plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %% [markdown]
# ### MNIST 다운로드

# %%
from tensorflow import keras
from tensorflow.keras.datasets.mnist import load_data
from sklearn.model_selection import train_test_split

# %%
(train_input, train_target), (test_input, test_target) = load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
print(train_input.shape, train_target.shape)
print(test_input.shape, test_target.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
# MNIST 이미지 표현
def show_images(dataset, label, nrow, ncol):
    # 캔버스 설정
    fig, axes = plt.subplots(nrows=nrow, ncols=ncol, figsize=(2*ncol, 2*nrow))
    ax = axes.ravel()

    xlabels = label[0:nrow*ncol]

    for i in range(nrow*ncol):
        image = dataset[i]
        ax[i].imshow(image, cmap='grey_r')
        ax[i].set_xticks([])
        ax[i].set_yticks([])
        ax[i].set_xlabel(xlabels[i])

    plt.tight_layout()
    plt.show()

# %%
show_images(train_input, train_target, 5, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\localRepository\StudyML\day05\99_1_MNIST_일반딥러닝.ipynb 셀 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> show_images(train_input, train_target, 5, 10)
#
# c:\localRepository\StudyML\day05\99_1_MNIST_일반딥러닝.ipynb 셀 9 in show_images(dataset, label, nrow, ncol)
#       <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> for i in range(nrow*ncol):
#      <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     image = dataset[i]
# ---> <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     ax[i].imshow(image, cmap='grey_r')
#      <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     ax[i].set_xticks([])
#      <a href='vscode-notebook-cell:/c%3A/localRepository/StudyML/day05/99_1_MNIST_%EC%9D%BC%EB%B0%98%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     ax[i].set_yticks([])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\_api\deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_axes.py:5475, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5473     aspect = rcParams['image.aspect']
#    5474 self.set_aspect(aspect)
# -> 5475 im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5476                       origin, extent, filternorm=filternorm,
#    5477                       filterrad=filterrad, resample=resample,
#    5478                       interpolation_stage=interpolation_stage,
#    5479                       **kwargs)
#    5481 im.set_data(X)
#    5482 im.set_alpha(alpha)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\image.py:929, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     913 def __init__(self, ax,
#     914              cmap=None,
#     915              norm=None,
#    (...)
#     924              **kwargs
#     925              ):
#     927     self._extent = extent
# --> 929     super().__init__(
#     930         ax,
#     931         cmap=cmap,
#     932         norm=norm,
#     933         interpolation=interpolation,
#     934         origin=origin,
#     935         filternorm=filternorm,
#     936         filterrad=filterrad,
#     937         resample=resample,
#     938         interpolation_stage=interpolation_stage,
#     939         **kwargs
#     940     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\image.py:246, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     233 def __init__(self, ax,
#     234              cmap=None,
#     235              norm=None,
#    (...)
#     243              **kwargs
#     244              ):
#     245     martist.Artist.__init__(self)
# --> 246     cm.ScalarMappable.__init__(self, norm, cmap)
#     247     if origin is None:
#     248         origin = mpl.rcParams['image.origin']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cm.py:359, in ScalarMappable.__init__(self, norm, cmap)
#     357 self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     358 self.cmap = None  # So that the setter knows we're initializing.
# --> 359 self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#     360 #: The last colorbar associated with this ScalarMappable. May be None.
#     361 self.colorbar = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cm.py:546, in ScalarMappable.set_cmap(self, cmap)
#     538 """
#     539 Set the colormap for luminance data.
#     540
#    (...)
#     543 cmap : `.Colormap` or str or None
#     544 """
#     545 in_init = self.cmap is None
# --> 546 cmap = get_cmap(cmap)
#     547 self.cmap = cmap
#     548 if not in_init:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     284 if isinstance(name, colors.Colormap):
#     285     return name
# --> 286 _api.check_in_list(sorted(_cmap_registry), name=name)
#     287 if lut is None:
#     288     return _cmap_registry[name]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\_api\__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
#     127 if _print_supported_values:
#     128     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 129 raise ValueError(msg)
#
# ValueError: 'grey_r' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
model = keras.Sequential(name='ANN')
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(100, activation='relu', name='hidden'))
model.add(keras.layers.Dense(10, activation='softmax', name='output'))
model.summary()
# Out:
# Model: "ANN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 255.0 나눠서 0~1로 값 축소하는 일은 안함
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('./data/best_ann_model.h5', save_best_only=True, verbose=1)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)
history = model.fit(train_input, train_target, epochs=20, verbose=1, validation_data=(test_input, test_target), batch_size=100, callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 581/600 [============================>.] - ETA: 0s - loss: 4.7788 - accuracy: 0.8470
# Epoch 1: val_loss improved from inf to 0.93474, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 4.6609 - accuracy: 0.8472 - val_loss: 0.9347 - val_accuracy: 0.8635
# Epoch 2/20
# 582/600 [============================>.] - ETA: 0s - loss: 0.5950 - accuracy: 0.8880
# Epoch 2: val_loss improved from 0.93474 to 0.55869, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5899 - accuracy: 0.8884 - val_loss: 0.5587 - val_accuracy: 0.9007
# Epoch 3/20
# 580/600 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.9182
# Epoch 3: val_loss improved from 0.55869 to 0.41637, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3579 - accuracy: 0.9184 - val_loss: 0.4164 - val_accuracy: 0.9154
# Epoch 4/20
# 599/600 [============================>.] - ETA: 0s - loss: 0.2654 - accuracy: 0.9345
# Epoch 4: val_loss improved from 0.41637 to 0.37366, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2654 - accuracy: 0.9345 - val_loss: 0.3737 - val_accuracy: 0.9210
# Epoch 5/20
# 584/600 [============================>.] - ETA: 0s - loss: 0.2178 - accuracy: 0.9436
# Epoch 5: val_loss improved from 0.37366 to 0.32880, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2183 - accuracy: 0.9436 - val_loss: 0.3288 - val_accuracy: 0.9332
# Epoch 6/20
# 577/600 [===========================>..] - ETA: 0s - loss: 0.1881 - accuracy: 0.9493
# Epoch 6: val_loss did not improve from 0.32880
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1876 - accuracy: 0.9496 - val_loss: 0.3507 - val_accuracy: 0.9394
# Epoch 7/20
# 588/600 [============================>.] - ETA: 0s - loss: 0.1748 - accuracy: 0.9533
# Epoch 7: val_loss improved from 0.32880 to 0.31816, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1753 - accuracy: 0.9532 - val_loss: 0.3182 - val_accuracy: 0.9419
# Epoch 8/20
# 594/600 [============================>.] - ETA: 0s - loss: 0.1614 - accuracy: 0.9562
# Epoch 8: val_loss did not improve from 0.31816
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1612 - accuracy: 0.9562 - val_loss: 0.3313 - val_accuracy: 0.9402
# Epoch 9/20
# 592/600 [============================>.] - ETA: 0s - loss: 0.1543 - accuracy: 0.9585
# Epoch 9: val_loss improved from 0.31816 to 0.27436, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1543 - accuracy: 0.9585 - val_loss: 0.2744 - val_accuracy: 0.9471
# Epoch 10/20
# 594/600 [============================>.] - ETA: 0s - loss: 0.1438 - accuracy: 0.9608
# Epoch 10: val_loss did not improve from 0.27436
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1446 - accuracy: 0.9606 - val_loss: 0.2879 - val_accuracy: 0.9495
# Epoch 11/20
# 589/600 [============================>.] - ETA: 0s - loss: 0.1478 - accuracy: 0.9612
# Epoch 11: val_loss improved from 0.27436 to 0.24734, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1477 - accuracy: 0.9611 - val_loss: 0.2473 - val_accuracy: 0.9471
# Epoch 12/20
# 598/600 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9640
# Epoch 12: val_loss improved from 0.24734 to 0.24291, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1286 - accuracy: 0.9640 - val_loss: 0.2429 - val_accuracy: 0.9533
# Epoch 13/20
# 600/600 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9668
# Epoch 13: val_loss did not improve from 0.24291
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1194 - accuracy: 0.9668 - val_loss: 0.2434 - val_accuracy: 0.9521
# Epoch 14/20
# 594/600 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9676
# Epoch 14: val_loss did not improve from 0.24291
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1199 - accuracy: 0.9677 - val_loss: 0.2661 - val_accuracy: 0.9484

# %%
model = keras.Sequential(name='ANN')
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(100, activation='relu', name='hidden'))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(10, activation='softmax', name='output'))
model.summary()
# Out:
# Model: "ANN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 255.0 나눠서 0~1로 값 축소하는 일은 안함
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('./data/best_ann_model.h5', save_best_only=True, verbose=1)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)
history = model.fit(train_input, train_target, epochs=20, verbose=1, validation_data=(test_input, test_target), batch_size=100, callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 598/600 [============================>.] - ETA: 0s - loss: 4.0236 - accuracy: 0.6063
# Epoch 1: val_loss improved from inf to 0.82448, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 4.0131 - accuracy: 0.6068 - val_loss: 0.8245 - val_accuracy: 0.7814
# Epoch 2/20
# 597/600 [============================>.] - ETA: 0s - loss: 0.9026 - accuracy: 0.7601
# Epoch 2: val_loss improved from 0.82448 to 0.57067, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.9021 - accuracy: 0.7603 - val_loss: 0.5707 - val_accuracy: 0.8719
# Epoch 3/20
# 588/600 [============================>.] - ETA: 0s - loss: 0.6674 - accuracy: 0.8139
# Epoch 3: val_loss improved from 0.57067 to 0.42668, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.6675 - accuracy: 0.8142 - val_loss: 0.4267 - val_accuracy: 0.8981
# Epoch 4/20
# 587/600 [============================>.] - ETA: 0s - loss: 0.5551 - accuracy: 0.8415
# Epoch 4: val_loss improved from 0.42668 to 0.41302, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.8416 - val_loss: 0.4130 - val_accuracy: 0.9080
# Epoch 5/20
# 585/600 [============================>.] - ETA: 0s - loss: 0.5032 - accuracy: 0.8592
# Epoch 5: val_loss improved from 0.41302 to 0.35766, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 1s 2ms/step - loss: 0.5041 - accuracy: 0.8590 - val_loss: 0.3577 - val_accuracy: 0.9199
# Epoch 6/20
# 590/600 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.8700
# Epoch 6: val_loss improved from 0.35766 to 0.32531, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4607 - accuracy: 0.8698 - val_loss: 0.3253 - val_accuracy: 0.9251
# Epoch 7/20
# 577/600 [===========================>..] - ETA: 0s - loss: 0.4080 - accuracy: 0.8831
# Epoch 7: val_loss improved from 0.32531 to 0.28666, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4079 - accuracy: 0.8829 - val_loss: 0.2867 - val_accuracy: 0.9354
# Epoch 8/20
# 587/600 [============================>.] - ETA: 0s - loss: 0.3883 - accuracy: 0.8912
# Epoch 8: val_loss did not improve from 0.28666
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3883 - accuracy: 0.8913 - val_loss: 0.3031 - val_accuracy: 0.9376
# Epoch 9/20
# 584/600 [============================>.] - ETA: 0s - loss: 0.3657 - accuracy: 0.8964
# Epoch 9: val_loss improved from 0.28666 to 0.26006, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3664 - accuracy: 0.8968 - val_loss: 0.2601 - val_accuracy: 0.9445
# Epoch 10/20
# 585/600 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.9043
# Epoch 10: val_loss improved from 0.26006 to 0.24153, saving model to ./data\best_ann_model.h5
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3519 - accuracy: 0.9045 - val_loss: 0.2415 - val_accuracy: 0.9452
# Epoch 11/20
# 597/600 [============================>.] - ETA: 0s - loss: 0.3369 - accuracy: 0.9059
# Epoch 11: val_loss did not improve from 0.24153
# 600/600 [==============================] - 1s 3ms/step - loss: 0.3368 - accuracy: 0.9060 - val_loss: 0.2474 - val_accuracy: 0.9478
# Epoch 12/20
# 584/600 [============================>.] - ETA: 0s - loss: 0.3209 - accuracy: 0.9120
# Epoch 12: val_loss did not improve from 0.24153
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3211 - accuracy: 0.9119 - val_loss: 0.2726 - val_accuracy: 0.9484

# %%
plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']
plt.figure(figsize=(10,5))

for each in plot_target:
    plt.plot(history.history[each], label=each)
plt.legend()
plt.show()

# %%
model.evaluate(test_input, test_target)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9533
# [0.24290859699249268, 0.9532999992370605]

# %%
# 예측된 결과값 리스트
pred_result = model.predict(test_input)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
pred_labels = np.argmax(pred_result, axis=-1)
pred_labels[:10]
pred_labels.shape
# Out:
# (10000,)

# %% [markdown]
# ##### 예측 실패한 이미지파악

# %%
wrong_result = []

for i in range(0, len(test_target)):
    if pred_labels[i] != test_target[i]:
        wrong_result.append(i)

len(wrong_result)
# Out:
# 467

# %%
import random

samples = random.choices(population=wrong_result, k=16)
len(samples)
# Out:
# 16

# %%
# 예측실패한 이미지 확인
plt.figure(figsize=(14,12))
for idx, n in enumerate(samples):
    plt.subplot(4,4, idx+1)
    plt.imshow(test_input[n].reshape(28,28), cmap='gray_r', interpolation='nearest')
    plt.title(f'label={test_target[n]} / predict={pred_labels[n]}')
    plt.axis('off')

plt.show()
